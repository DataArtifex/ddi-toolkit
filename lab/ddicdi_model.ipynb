# %%
from dartfx.ddi.ddicdi_specification import DdiCdiModel
import json
model = DdiCdiModel(root_dir='../specifications/ddi-cdi-1.0')

# %%
resource = "cdi:InstanceVariable"
print(json.dumps(model.get_resource_properties('cdi:ControlledVocabularyEntry'), indent=2))
#print(json.dumps(model.get_resource_associations_from('cdi:InstanceVariable', inherited=False, cardinalities=True), indent=2))
#print(json.dumps(model.get_association_cardinalities('cdi:InstanceVariable_has_PhysicalSegmentLayout'), indent=2))
#print(json.dumps(model.get_resource_domain_attributes('cdi:InstanceVariable', description=False, inherited=True), indent=2))
#print(json.dumps(model.get_enumeration('cdi:ComputationBaseList'), indent=2))
# Out:
# {
#   "rdf:type": [
#     "http://www.w3.org/2000/01/rdf-schema#Class",
#     "http://www.w3.org/2002/07/owl#Class",
#     "tag:ddialliance.org,2024:ucmis:StructuredDataType"
#   ],
#   "rdfs:label": "ControlledVocabularyEntry",
# ...

# %%
for association_uri in model.get_ucmis_associations():
    association = model.get_resource_properties(association_uri)
    print(json.dumps(association, indent=2))
    break
# Out:
# {
#   "rdf:type": [
#     "http://www.w3.org/1999/02/22-rdf-syntax-ns#Property",
#     "http://www.w3.org/2002/07/owl#ObjectProperty",
#     "tag:ddialliance.org,2024:ucmis:Association"
#   ],
#   "rdfs:label": "hasInternal",
#   "skos:altLabel": "Activity_hasInternal_ControlLogic",
#   "rdfs:comment": "An activity is embedded in the control construct which launches it.",
#   "rdfs:domain": "http://ddialliance.org/Specification/DDI-CDI/1.0/RDF/Activity",
#   "rdfs:range": "http://ddialliance.org/Specification/DDI-CDI/1.0/RDF/ControlLogic"
# }
