# %%
from dartfx.ddi.ddicdi_model import DdiCdiModel
import json
model = DdiCdiModel(root_dir='../specifications/ddi-cdi-1.0')

# %%
resource = "cdi:InstanceVariable"
#print(json.dumps(model.get_resource_associations('cdi:InstanceVariable', inherited=True, cardinalities=True), indent=2))
#print(json.dumps(model.get_association_cardinalities('cdi:InstanceVariable_has_PhysicalSegmentLayout'), indent=2))
print(json.dumps(model.get_resource_attributes('cdi:InstanceVariable', description=False, inherited=True), indent=2))
# Out:
# {
#   "cdi:InstanceVariable-physicalDataType": {
#     "uri": "cdi:InstanceVariable-physicalDataType",
#     "label": "physicalDataType",
#     "range": "cdi:ControlledVocabularyEntry",
#     "cardinality": {
#       "minOccurs": "0",
#       "maxOccurs": "1",
#       "display": "0..1"
#     },
#     "inherited": false,
#     "description": "The data type of this variable. Supports the optional use of an external controlled vocabulary."
#   },
#   "cdi:InstanceVariable-platformType": {
#     "uri": "cdi:InstanceVariable-platformType",
#     "label": "platformType",
#     "range": "cdi:ControlledVocabularyEntry",
#     "cardinality": {
#       "minOccurs": "0",
#       "maxOccurs": "1",
#       "display": "0..1"
#     },
#     "inherited": false,
#     "description": "Describes the application or technical system context in which the variable has been realized. Typically a statistical processing package or other processing environment."
#   },
#   "cdi:InstanceVariable-source": {
# ...
